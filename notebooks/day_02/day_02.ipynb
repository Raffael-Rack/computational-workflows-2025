# %% [markdown]
# # Day 2
#
# Today, we will start using nf-core pipelines to find differentially abundant genes in our dataset.
# We are using data from the following paper: https://www.nature.com/articles/s41593-023-01350-3#Sec10

# %% [markdown]
# 1. Please take some time to read through the paper and understand their approach, hypotheses and goals.

# %% [markdown]
# What was the objective of the study?
#
# Identify the transcriptomic effects of oxycodone withdrawal on mice with chronic pain.

# %% [markdown]
# What do the conditions mean?

# %% [markdown]
# oxy: Oxy stands for Oxycodone, an opioid. Mice in the oxy cohorts were treated with oxycodone after their surgery and then subjected to withdrawals.
#
#
# sal: Sal stands for Saline, which was used to provide a control group of mice without oxycodone treatment.

# %% [markdown]
# What do the genotypes mean?

# %% [markdown]
# SNI: SNI mice suffered chronic pain due to a prolonged spare nerve injury.
#
#
# Sham: Sham mice had no chronic pain and were used as a control group to control for the effects of the chronic pain.

# %% [markdown]
# Imagine you are the bioinformatician in the group who conducted this study. They hand you the raw files and ask you to analyze them.
#
# What would you do?
#
# On a conceptual level I would search for similarities and differences between the different groups to identify changes in the transcription behaviour. In practice this would mean comparing the data using a variety of measures, maybe do PCA or a clustering based on gene expression. Identify differences in maximum/minimum/mean/median gene-expressions or behaviours, check whether the differences are statistically significant and so on.
#
# Which groups would you compare to each other?
#
# Sham-sal to Sham-oxy to isolate and identify the effects of the treatment, Sham-sal to SNI-sal to look only at the effects of the chronic pain, SNI-sal to SNI-oxy to see the effects of treatment on mice suffering chronic pain, Sham-oxy to SNI-oxy to observe the different effects of treatment on mice that need it versus those that don't, and lastly Sham-Sal to SNI-oxy to see how the effects of treatment and injury interact.
#
# Please also mention which outcome you would expect to see from each comparison.
#
# I would expect that the non-control groups show disrupted transcription and impaired behaviour compared to the control groups. However, during active oxycodone treatment these effects should be lessened in SNI mice only to worsen during the withdrawal.

# %% [markdown]
# Your group gave you a very suboptimal excel sheet (conditions_runs_oxy_project.xlsx) to get the information you need for each run they uploaded to the SRA.<br>
# So, instead of directly diving into downloading the data and starting the analysis, you first need to sort the lazy table.<br>
# Use Python and Pandas to get the table into a more sensible order.<br>
# Then, perform some overview analysis and plot the results
# 1. How many samples do you have per condition?
# 2. How many samples do you have per genotype?
# 3. How often do you have each condition per genotype?

# %%
import pandas as pd

excel_data = "conditions_runs_oxy_project.xlsx"

df = pd.read_excel(excel_data, index_col="Run")

# %%
df = df.fillna(False)
df = df.replace("x",True)
df
# Out:
# /tmp/ipykernel_1673/4202485763.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /tmp/ipykernel_1673/4202485763.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace("x",True)
#             Patient  RNA-seq  DNA-seq  condition: Sal  Condition: Oxy  \
# Run
# SRR23195505       ?     True    False            True           False
# SRR23195506       ?     True    False           False            True
# SRR23195507       ?     True    False            True           False
# SRR23195508       ?     True    False           False            True
# SRR23195509       ?     True    False           False            True
# SRR23195510       ?     True    False            True           False
# SRR23195511       ?     True    False           False            True
# SRR23195512       ?     True    False            True           False
# SRR23195513       ?     True    False            True           False
# SRR23195514       ?     True    False           False            True
# SRR23195515       ?     True    False            True           False
# SRR23195516       ?     True    False           False            True
# SRR23195517       ?     True    False           False            True
# SRR23195518       ?     True    False            True           False
# SRR23195519       ?     True    False           False            True
# SRR23195520       ?     True    False            True           False
#
#              Genotype: SNI  Genotype: Sham
# Run
# SRR23195505           True           False
# SRR23195506          False            True
# SRR23195507          False            True
# SRR23195508           True           False
# SRR23195509           True           False
# SRR23195510           True           False
# SRR23195511          False            True
# SRR23195512          False            True
# SRR23195513           True           False
# SRR23195514          False            True
# SRR23195515          False            True
# SRR23195516           True           False
# SRR23195517           True           False
# SRR23195518           True           False
# SRR23195519          False            True
# SRR23195520          False            True

# %%
# Sample count for Genotype Sham: 8
# Sample count for Genotype NSI: 8

# %% [markdown]
# They were so kind to also provide you with the information of the number of bases per run, so that you can know how much space the data will take on your Cluster.<br>
# Add a new column to your fancy table with this information (base_counts.csv) and sort your dataframe according to this information and the condition.
#
# Then select the 2 smallest runs from your dataset and download them from SRA (maybe an nf-core pipeline can help here?...)

# %%
base_counts = pd.read_csv("base_counts.csv", index_col="Run")
data = pd.merge(df, base_counts, on="Run")
data
# Out:
#             Patient  RNA-seq  DNA-seq  condition: Sal  Condition: Oxy  \
# Run
# SRR23195505       ?     True    False            True           False
# SRR23195506       ?     True    False           False            True
# SRR23195507       ?     True    False            True           False
# SRR23195508       ?     True    False           False            True
# SRR23195509       ?     True    False           False            True
# SRR23195510       ?     True    False            True           False
# SRR23195511       ?     True    False           False            True
# SRR23195512       ?     True    False            True           False
# SRR23195513       ?     True    False            True           False
# SRR23195514       ?     True    False           False            True
# SRR23195515       ?     True    False            True           False
# SRR23195516       ?     True    False           False            True
# SRR23195517       ?     True    False           False            True
# SRR23195518       ?     True    False            True           False
# SRR23195519       ?     True    False           False            True
# SRR23195520       ?     True    False            True           False
#
#              Genotype: SNI  Genotype: Sham       Bases
# Run
# SRR23195505           True           False  6922564500
# SRR23195506          False            True  7859530800
# SRR23195507          False            True  8063298900
# SRR23195508           True           False  6927786900
# SRR23195509           True           False  7003550100
# SRR23195510           True           False  7377388500
# SRR23195511          False            True  6456390900
# SRR23195512          False            True  7462857900
# SRR23195513           True           False  8099181600
# SRR23195514          False            True  7226808600
# SRR23195515          False            True  8169101700
# SRR23195516           True           False  6203117700
# SRR23195517           True           False  6863840400
# SRR23195518           True           False  7908500400
# SRR23195519          False            True  6996050100
# SRR23195520          False            True  7858146000

# %%
data = data.sort_values("Bases")
data = data.sort_values("condition: Sal")
data
# The smallest runs are SRR23195516 and SRR23195511 w9th 6203117700 and 6456390900 bases respectively.
# Out:
#             Patient  RNA-seq  DNA-seq  condition: Sal  Condition: Oxy  \
# Run
# SRR23195516       ?     True    False           False            True
# SRR23195511       ?     True    False           False            True
# SRR23195517       ?     True    False           False            True
# SRR23195508       ?     True    False           False            True
# SRR23195519       ?     True    False           False            True
# SRR23195509       ?     True    False           False            True
# SRR23195514       ?     True    False           False            True
# SRR23195506       ?     True    False           False            True
# SRR23195505       ?     True    False            True           False
# SRR23195510       ?     True    False            True           False
# SRR23195512       ?     True    False            True           False
# SRR23195520       ?     True    False            True           False
# SRR23195518       ?     True    False            True           False
# SRR23195507       ?     True    False            True           False
# SRR23195513       ?     True    False            True           False
# SRR23195515       ?     True    False            True           False
#
#              Genotype: SNI  Genotype: Sham       Bases
# Run
# SRR23195516           True           False  6203117700
# SRR23195511          False            True  6456390900
# SRR23195517           True           False  6863840400
# SRR23195508           True           False  6927786900
# SRR23195519          False            True  6996050100
# SRR23195509           True           False  7003550100
# SRR23195514          False            True  7226808600
# SRR23195506          False            True  7859530800
# SRR23195505           True           False  6922564500
# SRR23195510           True           False  7377388500
# SRR23195512          False            True  7462857900
# SRR23195520          False            True  7858146000
# SRR23195518           True           False  7908500400
# SRR23195507          False            True  8063298900
# SRR23195513           True           False  8099181600
# SRR23195515          False            True  8169101700

# %%
# !nextflow run nf-core/fetchngs --input ids.csv -profile singularity --outdir day2_output --max_memory "4GB"
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/fetchngs` [special_angela] DSL2 - revision: 8ec2d934f9 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/fetchngs v1.12.0-g8ec2d93
# ------------------------------------------------------
# Core Nextflow options
#   revision       : master
#   runName        : special_angela
#   containerEngine: singularity
#   launchDir      : /workspaces/computational-workflows-2025/notebooks/day_02
#   workDir        : /workspaces/computational-workflows-2025/notebooks/day_02/work
#   projectDir     : /root/.nextflow/assets/nf-core/fetchngs
#   userName       : root
#   profile        : singularity
#   configFiles    :
#
# Input/output options
#   input          : ids.csv
#   outdir         : day2_output
#
# Max job request options
#   max_memory     : 4GB
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/fetchngs for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.5070524
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/fetchngs/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…NGS:SRA:SRA_IDS_TO_RUNINFO -
# [-        ] NFC…NGS:SRA:SRA_RUNINFO_TO_FTP -
# [-        ] NFC…FETCHNGS:SRA:SRA_FASTQ_FTP -
#
# [-        ] NFC…NGS:SRA:SRA_IDS_TO_RUNINFO -
# [-        ] NFC…NGS:SRA:SRA_RUNINFO_TO_FTP -
# [-        ] NFC…FETCHNGS:SRA:SRA_FASTQ_FTP -
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
#
# [-        ] NFC…NGS:SRA:SRA_IDS_TO_RUNINFO | 0 of 2
# [-        ] NFC…NGS:SRA:SRA_RUNINFO_TO_FTP -
# [-        ] NFC…FETCHNGS:SRA:SRA_FASTQ_FTP -
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
#
# executor >  local (2)
# [c5/929559] NFC…S_TO_RUNINFO (SRR23195511) | 0 of 2, retries: 2
# [-        ] NFC…NGS:SRA:SRA_RUNINFO_TO_FTP -
# [-        ] NFC…FETCHNGS:SRA:SRA_FASTQ_FTP -
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
# [a7/3b01a3] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195511)` terminated with an error exit status (255) -- Execution is retried (1)
# [ba/c6bc42] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195516)` terminated with an error exit status (255) -- Execution is retried (1)
#
# executor >  local (5)
# [10/b92c15] NFC…S_TO_RUNINFO (SRR23195511) | 0 of 2, retries: 4
# [-        ] NFC…NGS:SRA:SRA_RUNINFO_TO_FTP -
# [-        ] NFC…FETCHNGS:SRA:SRA_FASTQ_FTP -
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
# [a7/3b01a3] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195511)` terminated with an error exit status (255) -- Execution is retried (1)
# [ba/c6bc42] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195516)` terminated with an error exit status (255) -- Execution is retried (1)
# [c5/929559] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195511)` terminated with an error exit status (255) -- Execution is retried (2)
# [89/5265d0] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195516)` terminated with an error exit status (255) -- Execution is retried (2)
#
# executor >  local (6)
# [83/21e50c] NFC…S_TO_RUNINFO (SRR23195516) | 0 of 2, retries: 4
# [-        ] NFC…NGS:SRA:SRA_RUNINFO_TO_FTP -
# [-        ] NFC…FETCHNGS:SRA:SRA_FASTQ_FTP -
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
# [a7/3b01a3] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195511)` terminated with an error exit status (255) -- Execution is retried (1)
# [ba/c6bc42] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195516)` terminated with an error exit status (255) -- Execution is retried (1)
# [c5/929559] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195511)` terminated with an error exit status (255) -- Execution is retried (2)
# [89/5265d0] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195516)` terminated with an error exit status (255) -- Execution is retried (2)
# ERROR ~ Error executing process > 'NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195511)'
#
# Caused by:
#   Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195511)` terminated with an error exit status (255)
#
#
# Command executed:
#
#   echo SRR23195511 > id.txt
#   sra_ids_to_runinfo.py \
#       id.txt \
#       SRR23195511.runinfo.tsv \
#
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO":
#       python: $(python --version | sed 's/Python //g')
#   END_VERSIONS
#
# Command exit status:
#   255
#
# Command output:
#   (empty)
#
# Command error:
#   INFO:    Environment variable SINGULARITYENV_NXF_DEBUG is set, but APPTAINERENV_NXF_DEBUG is preferred
#   INFO:    Environment variable SINGULARITYENV_NXF_TASK_WORKDIR is set, but APPTAINERENV_NXF_TASK_WORKDIR is preferred
#   FATAL:   container creation failed: mount hook function failure: mount /proc/self/fd/4->/usr/local/apptainer/x86_64/var/lib/apptainer/mnt/session/rootfs error: while mounting image /proc/self/fd/4: failed to find loop device: could not attach image file to loop device: failed to attach loop device: could not open /dev/loop8: no such file or directory
#
# Work dir:
#   /workspaces/computational-workflows-2025/notebooks/day_02/work/10/b92c1553f5a083db2f11637d3799f1
#
# Container:
#   /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity/depot.galaxyproject.org-singularity-python-3.9--1.img
#
# Tip: you can try to figure out what's wrong by changing to the process work dir and showing the script file named `.command.sh`
#
#  -- Check '.nextflow.log' file for details
# -[nf-core/fetchngs] Pipeline completed with errors-
# WARN: =============================================================================
#   Please double-check the samplesheet that has been auto-created by the pipeline.
#
#   Public databases don't reliably hold information such as strandedness
#   information, controls etc
#
#   All of the sample metadata obtained from the ENA has been appended
#   as additional columns to help you manually curate the samplesheet before
#   running nf-core/other pipelines.
# ===================================================================================
# WARN: Killing running tasks (1)
#
# executor >  local (6)
# [83/21e50c] NFC…S_TO_RUNINFO (SRR23195516) | 0 of 2, retries: 4
# [-        ] NFC…NGS:SRA:SRA_RUNINFO_TO_FTP -
# [-        ] NFC…FETCHNGS:SRA:SRA_FASTQ_FTP -
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
# [a7/3b01a3] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195511)` terminated with an error exit status (255) -- Execution is retried (1)
# [ba/c6bc42] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195516)` terminated with an error exit status (255) -- Execution is retried (1)
# [c5/929559] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195511)` terminated with an error exit status (255) -- Execution is retried (2)
# [89/5265d0] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195516)` terminated with an error exit status (255) -- Execution is retried (2)
# ERROR ~ Error executing process > 'NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195511)'
#
# Caused by:
#   Process `NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO (SRR23195511)` terminated with an error exit status (255)
#
#
# Command executed:
#
#   echo SRR23195511 > id.txt
#   sra_ids_to_runinfo.py \
#       id.txt \
#       SRR23195511.runinfo.tsv \
#
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_FETCHNGS:SRA:SRA_IDS_TO_RUNINFO":
#       python: $(python --version | sed 's/Python //g')
#   END_VERSIONS
#
# Command exit status:
#   255
#
# Command output:
#   (empty)
#
# Command error:
#   INFO:    Environment variable SINGULARITYENV_NXF_DEBUG is set, but APPTAINERENV_NXF_DEBUG is preferred
#   INFO:    Environment variable SINGULARITYENV_NXF_TASK_WORKDIR is set, but APPTAINERENV_NXF_TASK_WORKDIR is preferred
#   FATAL:   container creation failed: mount hook function failure: mount /proc/self/fd/4->/usr/local/apptainer/x86_64/var/lib/apptainer/mnt/session/rootfs error: while mounting image /proc/self/fd/4: failed to find loop device: could not attach image file to loop device: failed to attach loop device: could not open /dev/loop8: no such file or directory
#
# Work dir:
#   /workspaces/computational-workflows-2025/notebooks/day_02/work/10/b92c1553f5a083db2f11637d3799f1
#
# Container:
#   /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity/depot.galaxyproject.org-singularity-python-3.9--1.img
#
# Tip: you can try to figure out what's wrong by changing to the process work dir and showing the script file named `.command.sh`
#
#  -- Check '.nextflow.log' file for details

# %% [markdown]
# While your files are downloading, get back to the paper and explain how you would try to reproduce the analysis.<br>
# When you are done with this shout, so we can discuss the different ideas.
#
# Unfortunately, the paper only has surface explanations of their processes, which means that we can use their tools on their data but we would have to guess which versions of those tools were used, as well as the parameters and options they used. This makes reproducing the data very difficult.

# %%
# !nextflow run nf-core/fetchngs --input ids.csv -profile apptainer --outdir day2_output --max_memory "4GB"
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/fetchngs` [silly_raman] DSL2 - revision: 8ec2d934f9 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/fetchngs v1.12.0-g8ec2d93
# ------------------------------------------------------
# Core Nextflow options
#   revision       : master
#   runName        : silly_raman
#   containerEngine: apptainer
#   launchDir      : /workspaces/computational-workflows-2025/notebooks/day_02
#   workDir        : /workspaces/computational-workflows-2025/notebooks/day_02/work
#   projectDir     : /root/.nextflow/assets/nf-core/fetchngs
#   userName       : root
#   profile        : apptainer
#   configFiles    :
#
# Input/output options
#   input          : ids.csv
#   outdir         : day2_output
#
# Max job request options
#   max_memory     : 4GB
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/fetchngs for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.5070524
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/fetchngs/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…NGS:SRA:SRA_IDS_TO_RUNINFO -
# [-        ] NFC…NGS:SRA:SRA_RUNINFO_TO_FTP -
#
# [-        ] NFC…NGS:SRA:SRA_IDS_TO_RUNINFO -
# [-        ] NFC…NGS:SRA:SRA_RUNINFO_TO_FTP -
# [-        ] NFC…FETCHNGS:SRA:SRA_FASTQ_FTP -
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
#
# executor >  local (2)
# [50/e3ac37] NFC…S_TO_RUNINFO (SRR23195511) | 0 of 2
# [-        ] NFC…NGS:SRA:SRA_RUNINFO_TO_FTP -
# [-        ] NFC…FETCHNGS:SRA:SRA_FASTQ_FTP -
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
#
# executor >  local (4)
# [db/84f6c8] NFC…S_TO_RUNINFO (SRR23195516) | 2 of 2 ✔
# [6d/35f0bd] NFC…SRA:SRA_RUNINFO_TO_FTP (2) | 0 of 2
# [-        ] NFC…FETCHNGS:SRA:SRA_FASTQ_FTP -
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
#
# executor >  local (4)
# [db/84f6c8] NFC…S_TO_RUNINFO (SRR23195516) | 2 of 2 ✔
# [6d/35f0bd] NFC…SRA:SRA_RUNINFO_TO_FTP (2) | 2 of 2 ✔
# [-        ] NFC…FETCHNGS:SRA:SRA_FASTQ_FTP -
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
# Pulling Apptainer image docker://quay.io/biocontainers/wget:1.20.1 [cache /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity/quay.io-biocontainers-wget-1.20.1.img]
# WARN: Apptainer cache directory has not been defined -- Remote image will be stored in the path: /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity -- Use the environment variable NXF_APPTAINER_CACHEDIR to specify a different location
#
# executor >  local (6)
# [db/84f6c8] NFC…S_TO_RUNINFO (SRR23195516) | 2 of 2 ✔
# [6d/35f0bd] NFC…SRA:SRA_RUNINFO_TO_FTP (2) | 2 of 2 ✔
# [d2/20f508] NFC… (SRX19144486_SRR23195516) | 0 of 2
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
# Pulling Apptainer image docker://quay.io/biocontainers/wget:1.20.1 [cache /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity/quay.io-biocontainers-wget-1.20.1.img]
# WARN: Apptainer cache directory has not been defined -- Remote image will be stored in the path: /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity -- Use the environment variable NXF_APPTAINER_CACHEDIR to specify a different location
#
# executor >  local (6)
# [db/84f6c8] NFC…S_TO_RUNINFO (SRR23195516) | 2 of 2 ✔
# [6d/35f0bd] NFC…SRA:SRA_RUNINFO_TO_FTP (2) | 2 of 2 ✔
# [d2/20f508] NFC… (SRX19144486_SRR23195516) | 0 of 2
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
# Pulling Apptainer image docker://quay.io/biocontainers/wget:1.20.1 [cache /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity/quay.io-biocontainers-wget-1.20.1.img]
# WARN: Apptainer cache directory has not been defined -- Remote image will be stored in the path: /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity -- Use the environment variable NXF_APPTAINER_CACHEDIR to specify a different location
#
# executor >  local (7)
# [db/84f6c8] NFC…S_TO_RUNINFO (SRR23195516) | 2 of 2 ✔
# [6d/35f0bd] NFC…SRA:SRA_RUNINFO_TO_FTP (2) | 2 of 2 ✔
# [74/de091d] NFC… (SRX19144486_SRR23195516) | 0 of 2, retries: 2
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
# Pulling Apptainer image docker://quay.io/biocontainers/wget:1.20.1 [cache /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity/quay.io-biocontainers-wget-1.20.1.img]
# WARN: Apptainer cache directory has not been defined -- Remote image will be stored in the path: /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity -- Use the environment variable NXF_APPTAINER_CACHEDIR to specify a different location
# [d2/20f508] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_FASTQ_FTP (SRX19144486_SRR23195516)` terminated with an error exit status (4) -- Execution is retried (1)
# [6f/fb84fa] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_FASTQ_FTP (SRX19144488_SRR23195511)` terminated with an error exit status (4) -- Execution is retried (1)
#
# executor >  local (8)
# [db/84f6c8] NFC…S_TO_RUNINFO (SRR23195516) | 2 of 2 ✔
# [6d/35f0bd] NFC…SRA:SRA_RUNINFO_TO_FTP (2) | 2 of 2 ✔
# [36/f3601a] NFC… (SRX19144488_SRR23195511) | 0 of 2, retries: 3
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
# Pulling Apptainer image docker://quay.io/biocontainers/wget:1.20.1 [cache /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity/quay.io-biocontainers-wget-1.20.1.img]
# WARN: Apptainer cache directory has not been defined -- Remote image will be stored in the path: /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity -- Use the environment variable NXF_APPTAINER_CACHEDIR to specify a different location
# [d2/20f508] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_FASTQ_FTP (SRX19144486_SRR23195516)` terminated with an error exit status (4) -- Execution is retried (1)
# [6f/fb84fa] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_FASTQ_FTP (SRX19144488_SRR23195511)` terminated with an error exit status (4) -- Execution is retried (1)
# [74/de091d] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_FASTQ_FTP (SRX19144486_SRR23195516)` terminated with an error exit status (4) -- Execution is retried (2)
# ERROR ~ Error executing process > 'NFCORE_FETCHNGS:SRA:SRA_FASTQ_FTP (SRX19144486_SRR23195516)'
#
# Caused by:
#   Process requirement exceeds available CPUs -- req: 6; avail: 4
#
#
# Command executed:
#
#   wget \
#       -t 5 -nv -c -T 60 \
#       -O SRX19144486_SRR23195516_1.fastq.gz \
#       ftp.sra.ebi.ac.uk/vol1/fastq/SRR231/016/SRR23195516/SRR23195516_1.fastq.gz
#
#   echo "d04951f4200402f36d8f1830315a708f  SRX19144486_SRR23195516_1.fastq.gz" > SRX19144486_SRR23195516_1.fastq.gz.md5
#   md5sum -c SRX19144486_SRR23195516_1.fastq.gz.md5
#
#   wget \
#       -t 5 -nv -c -T 60 \
#       -O SRX19144486_SRR23195516_2.fastq.gz \
#       ftp.sra.ebi.ac.uk/vol1/fastq/SRR231/016/SRR23195516/SRR23195516_2.fastq.gz
#
#   echo "29ada651e1b89ea83c6ccb4977f09e69  SRX19144486_SRR23195516_2.fastq.gz" > SRX19144486_SRR23195516_2.fastq.gz.md5
#   md5sum -c SRX19144486_SRR23195516_2.fastq.gz.md5
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_FETCHNGS:SRA:SRA_FASTQ_FTP":
#       wget: $(echo $(wget --version | head -n 1 | sed 's/^GNU Wget //; s/ .*$//'))
#   END_VERSIONS
#
# Command exit status:
#   -
#
# Command output:
#   (empty)
#
# Command error:
#   WARNING: Skipping mount /usr/local/apptainer/x86_64/var/lib/apptainer/mnt/session/etc/resolv.conf [files]: /etc/resolv.conf doesn't exist in container
#   wget: unable to resolve host address 'ftp.sra.ebi.ac.uk'
#
# Work dir:
#   /workspaces/computational-workflows-2025/notebooks/day_02/work/d6/2bc374e08b27aec60a8cb7d037411b
#
# Container:
#   /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity/quay.io-biocontainers-wget-1.20.1.img
#
# Tip: you can replicate the issue by changing to the process work dir and entering the command `bash .command.run`
#
#  -- Check '.nextflow.log' file for details
# -[nf-core/fetchngs] Pipeline completed with errors-
# WARN: =============================================================================
#   Please double-check the samplesheet that has been auto-created by the pipeline.
#
#   Public databases don't reliably hold information such as strandedness
#   information, controls etc
#
#   All of the sample metadata obtained from the ENA has been appended
#   as additional columns to help you manually curate the samplesheet before
#   running nf-core/other pipelines.
# ===================================================================================
# WARN: Killing running tasks (1)
#
# executor >  local (8)
# [db/84f6c8] NFC…S_TO_RUNINFO (SRR23195516) | 2 of 2 ✔
# [6d/35f0bd] NFC…SRA:SRA_RUNINFO_TO_FTP (2) | 2 of 2 ✔
# [36/f3601a] NFC… (SRX19144488_SRR23195511) | 0 of 2, retries: 3
# [-        ] NFC…USTOM_SRATOOLSNCBISETTINGS -
# [-        ] NFC…SRATOOLS:SRATOOLS_PREFETCH -
# [-        ] NFC…TOOLS:SRATOOLS_FASTERQDUMP -
# [-        ] NFCORE_FETCHNGS:SRA:ASPERA_CLI -
# [-        ] NFC…NGS:SRA:SRA_TO_SAMPLESHEET -
# [-        ] NFC…RA:MULTIQC_MAPPINGS_CONFIG -
# Pulling Apptainer image docker://quay.io/biocontainers/wget:1.20.1 [cache /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity/quay.io-biocontainers-wget-1.20.1.img]
# WARN: Apptainer cache directory has not been defined -- Remote image will be stored in the path: /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity -- Use the environment variable NXF_APPTAINER_CACHEDIR to specify a different location
# [d2/20f508] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_FASTQ_FTP (SRX19144486_SRR23195516)` terminated with an error exit status (4) -- Execution is retried (1)
# [6f/fb84fa] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_FASTQ_FTP (SRX19144488_SRR23195511)` terminated with an error exit status (4) -- Execution is retried (1)
# [74/de091d] NOTE: Process `NFCORE_FETCHNGS:SRA:SRA_FASTQ_FTP (SRX19144486_SRR23195516)` terminated with an error exit status (4) -- Execution is retried (2)
# ERROR ~ Error executing process > 'NFCORE_FETCHNGS:SRA:SRA_FASTQ_FTP (SRX19144486_SRR23195516)'
#
# Caused by:
#   Process requirement exceeds available CPUs -- req: 6; avail: 4
#
#
# Command executed:
#
#   wget \
#       -t 5 -nv -c -T 60 \
#       -O SRX19144486_SRR23195516_1.fastq.gz \
#       ftp.sra.ebi.ac.uk/vol1/fastq/SRR231/016/SRR23195516/SRR23195516_1.fastq.gz
#
#   echo "d04951f4200402f36d8f1830315a708f  SRX19144486_SRR23195516_1.fastq.gz" > SRX19144486_SRR23195516_1.fastq.gz.md5
#   md5sum -c SRX19144486_SRR23195516_1.fastq.gz.md5
#
#   wget \
#       -t 5 -nv -c -T 60 \
#       -O SRX19144486_SRR23195516_2.fastq.gz \
#       ftp.sra.ebi.ac.uk/vol1/fastq/SRR231/016/SRR23195516/SRR23195516_2.fastq.gz
#
#   echo "29ada651e1b89ea83c6ccb4977f09e69  SRX19144486_SRR23195516_2.fastq.gz" > SRX19144486_SRR23195516_2.fastq.gz.md5
#   md5sum -c SRX19144486_SRR23195516_2.fastq.gz.md5
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_FETCHNGS:SRA:SRA_FASTQ_FTP":
#       wget: $(echo $(wget --version | head -n 1 | sed 's/^GNU Wget //; s/ .*$//'))
#   END_VERSIONS
#
# Command exit status:
#   -
#
# Command output:
#   (empty)
#
# Command error:
#   WARNING: Skipping mount /usr/local/apptainer/x86_64/var/lib/apptainer/mnt/session/etc/resolv.conf [files]: /etc/resolv.conf doesn't exist in container
#   wget: unable to resolve host address 'ftp.sra.ebi.ac.uk'
#
# Work dir:
#   /workspaces/computational-workflows-2025/notebooks/day_02/work/d6/2bc374e08b27aec60a8cb7d037411b
#
# Container:
#   /workspaces/computational-workflows-2025/notebooks/day_02/work/singularity/quay.io-biocontainers-wget-1.20.1.img
#
# Tip: you can replicate the issue by changing to the process work dir and entering the command `bash .command.run`
#
#  -- Check '.nextflow.log' file for details
